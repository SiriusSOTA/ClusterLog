# %% [markdown]
# ## Clear messages

# %%
import os
import pandas as pd
import numpy as np
import json
import hashlib
from tqdm.notebook import tqdm

# %%
objects = []

# %%
for file in os.listdir('data'):
    hits = []
    with open('data/'+ file) as json_file:
        obj = json.load(json_file)
        hits = obj['hits']['hits']
        objects.extend(list(map(lambda hit: {'timestamp': hit['_source']['@timestamp'], 'message': hit['_source']['message']}, hits)))

# %%
df = pd.DataFrame.from_records(objects)

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %% [markdown]
# ### Tokenized pattern

# %%
df['Tokenized Pattern'] = df['message'].str.replace(r' ', '*_*').str.split('*')
df
# Out:
#                              timestamp  \
# 0     2017-01-30 16:48:25.023000+00:00
# 1     2017-01-30 16:48:25.023000+00:00
# 2     2017-01-30 16:48:25.023000+00:00
# 3     2017-01-30 16:48:25.023000+00:00
# 4     2017-01-30 16:48:25.023000+00:00
# ...                                ...
# 99995 2017-01-30 16:48:26.191000+00:00
# 99996 2017-01-30 16:48:26.191000+00:00
# 99997 2017-01-30 16:48:26.191000+00:00
# 99998 2017-01-30 16:48:26.191000+00:00
# 99999 2017-01-30 16:48:26.191000+00:00
#
#                                                  message  \
# 0      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 1      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 2      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 3      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 4      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# ...                                                  ...
# 99995  WCCILevent (0), 2017.01.30 17:48:26.191, SYS, ...
# 99996  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
# 99997  WCCILevent (0), 2017.01.30 17:48:26.191, SYS, ...
# 99998  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
# 99999  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
#
#                                        Tokenized Pattern
# 0      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 1      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 2      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 3      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 4      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# ...                                                  ...
# 99995  [WCCILevent, _, (0),, _, 2017.01.30, _, 17:48:...
# 99996  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
# 99997  [WCCILevent, _, (0),, _, 2017.01.30, _, 17:48:...
# 99998  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
# 99999  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
#
# [100000 rows x 3 columns]

# %% [markdown]
# ### Cleaned

# %%
df['Cleaned'] = df['message'].str.replace(r'\S+\.\S+', ' ')
df
# Out:
#                              timestamp  \
# 0     2017-01-30 16:48:25.023000+00:00
# 1     2017-01-30 16:48:25.023000+00:00
# 2     2017-01-30 16:48:25.023000+00:00
# 3     2017-01-30 16:48:25.023000+00:00
# 4     2017-01-30 16:48:25.023000+00:00
# ...                                ...
# 99995 2017-01-30 16:48:26.191000+00:00
# 99996 2017-01-30 16:48:26.191000+00:00
# 99997 2017-01-30 16:48:26.191000+00:00
# 99998 2017-01-30 16:48:26.191000+00:00
# 99999 2017-01-30 16:48:26.191000+00:00
#
#                                                  message  \
# 0      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 1      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 2      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 3      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 4      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# ...                                                  ...
# 99995  WCCILevent (0), 2017.01.30 17:48:26.191, SYS, ...
# 99996  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
# 99997  WCCILevent (0), 2017.01.30 17:48:26.191, SYS, ...
# 99998  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
# 99999  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
#
#                                        Tokenized Pattern  \
# 0      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 1      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 2      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 3      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 4      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# ...                                                  ...
# 99995  [WCCILevent, _, (0),, _, 2017.01.30, _, 17:48:...
# 99996  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
# 99997  [WCCILevent, _, (0),, _, 2017.01.30, _, 17:48:...
# 99998  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
# 99999  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
#
#                                                  Cleaned
# 0      WCCILdata (0),     SYS, SEVERE, 118, Last erro...
# 1      WCCILdata (0),     SYS, SEVERE, 118, Last erro...
# 2      WCCILdata (0),     SYS, SEVERE, 118, Last erro...
# 3      WCCILdata (0),     SYS, SEVERE, 118, Last erro...
# 4      WCCILdata (0),     SYS, SEVERE, 118, Last erro...
# ...                                                  ...
# 99995  WCCILevent (0),     SYS, INFO, 4, Connected to...
# 99996  WCCOAascii (1),     SYS, INFO, 102, Waiting fo...
# 99997  WCCILevent (0),     SYS, INFO, 4, Connected to...
# 99998  WCCOAascii (1),     SYS, INFO, 102, Waiting fo...
# 99999  WCCOAascii (1),     SYS, INFO, 102, Waiting fo...
#
# [100000 rows x 4 columns]

# %%
df['Cleaned'] = df['Cleaned'].str.replace(r'([a-zA-Z_.|:;-]*\d+[a-zA-Z_.|:;-]*)+', ' ')
df
# Out:
#                              timestamp  \
# 0     2017-01-30 16:48:25.023000+00:00
# 1     2017-01-30 16:48:25.023000+00:00
# 2     2017-01-30 16:48:25.023000+00:00
# 3     2017-01-30 16:48:25.023000+00:00
# 4     2017-01-30 16:48:25.023000+00:00
# ...                                ...
# 99995 2017-01-30 16:48:26.191000+00:00
# 99996 2017-01-30 16:48:26.191000+00:00
# 99997 2017-01-30 16:48:26.191000+00:00
# 99998 2017-01-30 16:48:26.191000+00:00
# 99999 2017-01-30 16:48:26.191000+00:00
#
#                                                  message  \
# 0      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 1      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 2      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 3      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 4      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# ...                                                  ...
# 99995  WCCILevent (0), 2017.01.30 17:48:26.191, SYS, ...
# 99996  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
# 99997  WCCILevent (0), 2017.01.30 17:48:26.191, SYS, ...
# 99998  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
# 99999  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
#
#                                        Tokenized Pattern  \
# 0      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 1      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 2      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 3      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 4      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# ...                                                  ...
# 99995  [WCCILevent, _, (0),, _, 2017.01.30, _, 17:48:...
# 99996  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
# 99997  [WCCILevent, _, (0),, _, 2017.01.30, _, 17:48:...
# 99998  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
# 99999  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
#
#                                                  Cleaned
# 0      WCCILdata ( ),     SYS, SEVERE,  , Last error ...
# 1      WCCILdata ( ),     SYS, SEVERE,  , Last error ...
# 2      WCCILdata ( ),     SYS, SEVERE,  , Last error ...
# 3      WCCILdata ( ),     SYS, SEVERE,  , Last error ...
# 4      WCCILdata ( ),     SYS, SEVERE,  , Last error ...
# ...                                                  ...
# 99995  WCCILevent ( ),     SYS, INFO,  , Connected to...
# 99996  WCCOAascii ( ),     SYS, INFO,  , Waiting for ...
# 99997  WCCILevent ( ),     SYS, INFO,  , Connected to...
# 99998  WCCOAascii ( ),     SYS, INFO,  , Waiting for ...
# 99999  WCCOAascii ( ),     SYS, INFO,  , Waiting for ...
#
# [100000 rows x 4 columns]

# %%
df['Cleaned'] = df['Cleaned'].str.replace(r'[^\w ]', ' ')
df
# Out:
#                              timestamp  \
# 0     2017-01-30 16:48:25.023000+00:00
# 1     2017-01-30 16:48:25.023000+00:00
# 2     2017-01-30 16:48:25.023000+00:00
# 3     2017-01-30 16:48:25.023000+00:00
# 4     2017-01-30 16:48:25.023000+00:00
# ...                                ...
# 99995 2017-01-30 16:48:26.191000+00:00
# 99996 2017-01-30 16:48:26.191000+00:00
# 99997 2017-01-30 16:48:26.191000+00:00
# 99998 2017-01-30 16:48:26.191000+00:00
# 99999 2017-01-30 16:48:26.191000+00:00
#
#                                                  message  \
# 0      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 1      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 2      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 3      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 4      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# ...                                                  ...
# 99995  WCCILevent (0), 2017.01.30 17:48:26.191, SYS, ...
# 99996  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
# 99997  WCCILevent (0), 2017.01.30 17:48:26.191, SYS, ...
# 99998  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
# 99999  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
#
#                                        Tokenized Pattern  \
# 0      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 1      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 2      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 3      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 4      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# ...                                                  ...
# 99995  [WCCILevent, _, (0),, _, 2017.01.30, _, 17:48:...
# 99996  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
# 99997  [WCCILevent, _, (0),, _, 2017.01.30, _, 17:48:...
# 99998  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
# 99999  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
#
#                                                  Cleaned
# 0      WCCILdata          SYS  SEVERE     Last error ...
# 1      WCCILdata          SYS  SEVERE     Last error ...
# 2      WCCILdata          SYS  SEVERE     Last error ...
# 3      WCCILdata          SYS  SEVERE     Last error ...
# 4      WCCILdata          SYS  SEVERE     Last error ...
# ...                                                  ...
# 99995  WCCILevent          SYS  INFO     Connected to...
# 99996  WCCOAascii          SYS  INFO     Waiting for ...
# 99997  WCCILevent          SYS  INFO     Connected to...
# 99998  WCCOAascii          SYS  INFO     Waiting for ...
# 99999  WCCOAascii          SYS  INFO     Waiting for ...
#
# [100000 rows x 4 columns]

# %%
df['Cleaned'] = df['Cleaned'].str.replace(r' +', r' ')
df
# Out:
#                              timestamp  \
# 0     2017-01-30 16:48:25.023000+00:00
# 1     2017-01-30 16:48:25.023000+00:00
# 2     2017-01-30 16:48:25.023000+00:00
# 3     2017-01-30 16:48:25.023000+00:00
# 4     2017-01-30 16:48:25.023000+00:00
# ...                                ...
# 99995 2017-01-30 16:48:26.191000+00:00
# 99996 2017-01-30 16:48:26.191000+00:00
# 99997 2017-01-30 16:48:26.191000+00:00
# 99998 2017-01-30 16:48:26.191000+00:00
# 99999 2017-01-30 16:48:26.191000+00:00
#
#                                                  message  \
# 0      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 1      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 2      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 3      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 4      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# ...                                                  ...
# 99995  WCCILevent (0), 2017.01.30 17:48:26.191, SYS, ...
# 99996  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
# 99997  WCCILevent (0), 2017.01.30 17:48:26.191, SYS, ...
# 99998  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
# 99999  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
#
#                                        Tokenized Pattern  \
# 0      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 1      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 2      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 3      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 4      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# ...                                                  ...
# 99995  [WCCILevent, _, (0),, _, 2017.01.30, _, 17:48:...
# 99996  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
# 99997  [WCCILevent, _, (0),, _, 2017.01.30, _, 17:48:...
# 99998  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
# 99999  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
#
#                                                  Cleaned
# 0      WCCILdata SYS SEVERE Last error already repeat...
# 1      WCCILdata SYS SEVERE Last error already repeat...
# 2      WCCILdata SYS SEVERE Last error already repeat...
# 3      WCCILdata SYS SEVERE Last error already repeat...
# 4      WCCILdata SYS SEVERE Last error already repeat...
# ...                                                  ...
# 99995  WCCILevent SYS INFO Connected to SYS Ascii num...
# 99996  WCCOAascii SYS INFO Waiting for user names pas...
# 99997  WCCILevent SYS INFO Connected to SYS Ascii num...
# 99998  WCCOAascii SYS INFO Waiting for user names pas...
# 99999  WCCOAascii SYS INFO Waiting for user names pas...
#
# [100000 rows x 4 columns]

# %%
df['Sequence'] = df['Cleaned'].str.lower().str.split()
df
# Out:
#                              timestamp  \
# 0     2017-01-30 16:48:25.023000+00:00
# 1     2017-01-30 16:48:25.023000+00:00
# 2     2017-01-30 16:48:25.023000+00:00
# 3     2017-01-30 16:48:25.023000+00:00
# 4     2017-01-30 16:48:25.023000+00:00
# ...                                ...
# 99995 2017-01-30 16:48:26.191000+00:00
# 99996 2017-01-30 16:48:26.191000+00:00
# 99997 2017-01-30 16:48:26.191000+00:00
# 99998 2017-01-30 16:48:26.191000+00:00
# 99999 2017-01-30 16:48:26.191000+00:00
#
#                                                  message  \
# 0      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 1      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 2      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 3      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 4      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# ...                                                  ...
# 99995  WCCILevent (0), 2017.01.30 17:48:26.191, SYS, ...
# 99996  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
# 99997  WCCILevent (0), 2017.01.30 17:48:26.191, SYS, ...
# 99998  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
# 99999  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
#
#                                        Tokenized Pattern  \
# 0      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 1      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 2      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 3      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 4      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# ...                                                  ...
# 99995  [WCCILevent, _, (0),, _, 2017.01.30, _, 17:48:...
# 99996  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
# 99997  [WCCILevent, _, (0),, _, 2017.01.30, _, 17:48:...
# 99998  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
# 99999  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
#
#                                                  Cleaned  \
# 0      WCCILdata SYS SEVERE Last error already repeat...
# 1      WCCILdata SYS SEVERE Last error already repeat...
# 2      WCCILdata SYS SEVERE Last error already repeat...
# 3      WCCILdata SYS SEVERE Last error already repeat...
# 4      WCCILdata SYS SEVERE Last error already repeat...
# ...                                                  ...
# 99995  WCCILevent SYS INFO Connected to SYS Ascii num...
# 99996  WCCOAascii SYS INFO Waiting for user names pas...
# 99997  WCCILevent SYS INFO Connected to SYS Ascii num...
# 99998  WCCOAascii SYS INFO Waiting for user names pas...
# 99999  WCCOAascii SYS INFO Waiting for user names pas...
#
#                                                 Sequence
# 0      [wccildata, sys, severe, last, error, already,...
# 1      [wccildata, sys, severe, last, error, already,...
# 2      [wccildata, sys, severe, last, error, already,...
# 3      [wccildata, sys, severe, last, error, already,...
# 4      [wccildata, sys, severe, last, error, already,...
# ...                                                  ...
# 99995  [wccilevent, sys, info, connected, to, sys, as...
# 99996  [wccoaascii, sys, info, waiting, for, user, na...
# 99997  [wccilevent, sys, info, connected, to, sys, as...
# 99998  [wccoaascii, sys, info, waiting, for, user, na...
# 99999  [wccoaascii, sys, info, waiting, for, user, na...
#
# [100000 rows x 5 columns]

# %% [markdown]
# ### Hash

# %%
df['Hash'] = df['Cleaned'].str.lower().str.encode('utf-8').apply(lambda x: hashlib.md5(x).hexdigest())
df
# Out:
#                              timestamp  \
# 0     2017-01-30 16:48:25.023000+00:00
# 1     2017-01-30 16:48:25.023000+00:00
# 2     2017-01-30 16:48:25.023000+00:00
# 3     2017-01-30 16:48:25.023000+00:00
# 4     2017-01-30 16:48:25.023000+00:00
# ...                                ...
# 99995 2017-01-30 16:48:26.191000+00:00
# 99996 2017-01-30 16:48:26.191000+00:00
# 99997 2017-01-30 16:48:26.191000+00:00
# 99998 2017-01-30 16:48:26.191000+00:00
# 99999 2017-01-30 16:48:26.191000+00:00
#
#                                                  message  \
# 0      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 1      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 2      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 3      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# 4      WCCILdata (0), 2017.01.30 17:48:25.023, SYS, S...
# ...                                                  ...
# 99995  WCCILevent (0), 2017.01.30 17:48:26.191, SYS, ...
# 99996  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
# 99997  WCCILevent (0), 2017.01.30 17:48:26.191, SYS, ...
# 99998  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
# 99999  WCCOAascii (1), 2017.01.30 17:48:26.191, SYS, ...
#
#                                        Tokenized Pattern  \
# 0      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 1      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 2      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 3      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# 4      [WCCILdata, _, (0),, _, 2017.01.30, _, 17:48:2...
# ...                                                  ...
# 99995  [WCCILevent, _, (0),, _, 2017.01.30, _, 17:48:...
# 99996  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
# 99997  [WCCILevent, _, (0),, _, 2017.01.30, _, 17:48:...
# 99998  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
# 99999  [WCCOAascii, _, (1),, _, 2017.01.30, _, 17:48:...
#
#                                                  Cleaned  \
# 0      WCCILdata SYS SEVERE Last error already repeat...
# 1      WCCILdata SYS SEVERE Last error already repeat...
# 2      WCCILdata SYS SEVERE Last error already repeat...
# 3      WCCILdata SYS SEVERE Last error already repeat...
# 4      WCCILdata SYS SEVERE Last error already repeat...
# ...                                                  ...
# 99995  WCCILevent SYS INFO Connected to SYS Ascii num...
# 99996  WCCOAascii SYS INFO Waiting for user names pas...
# 99997  WCCILevent SYS INFO Connected to SYS Ascii num...
# 99998  WCCOAascii SYS INFO Waiting for user names pas...
# 99999  WCCOAascii SYS INFO Waiting for user names pas...
#
#                                                 Sequence  \
# 0      [wccildata, sys, severe, last, error, already,...
# 1      [wccildata, sys, severe, last, error, already,...
# 2      [wccildata, sys, severe, last, error, already,...
# 3      [wccildata, sys, severe, last, error, already,...
# 4      [wccildata, sys, severe, last, error, already,...
# ...                                                  ...
# 99995  [wccilevent, sys, info, connected, to, sys, as...
# 99996  [wccoaascii, sys, info, waiting, for, user, na...
# 99997  [wccilevent, sys, info, connected, to, sys, as...
# 99998  [wccoaascii, sys, info, waiting, for, user, na...
# 99999  [wccoaascii, sys, info, waiting, for, user, na...
#
#                                    Hash
# 0      a39b74d945ecdcb73e56f21d07624fdf
# 1      a39b74d945ecdcb73e56f21d07624fdf
# 2      a39b74d945ecdcb73e56f21d07624fdf
# 3      a39b74d945ecdcb73e56f21d07624fdf
# 4      a39b74d945ecdcb73e56f21d07624fdf
# ...                                 ...
# 99995  1d6efcf88a8f12baeb53df73d80b2b7d
# 99996  2a88aaa7a962f32fe67d186de1c24999
# 99997  1d6efcf88a8f12baeb53df73d80b2b7d
# 99998  2a88aaa7a962f32fe67d186de1c24999
# 99999  2a88aaa7a962f32fe67d186de1c24999
#
# [100000 rows x 6 columns]

# %%
from gensim.models import Word2Vec

# %%
corpus = list(map(lambda x: x[1], df['Sequence'].iteritems()))

# %%
model = Word2Vec(sentences=corpus, vector_size=100, window=5, min_count=1, workers=4)

# %%
result = []
for sentence in tqdm(corpus):
    cur = np.zeros((100,))
    for word in sentence:
        cur += model.wv[word]
    result.append(cur / len(sentence))
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
emdeddings = np.array(result)
emdeddings.shape
# Out:
# (100000, 100)

# %%
emdeddings.dump('embeddings/v1.np')
